# %% [markdown]
# <a href="https://colab.research.google.com/github/AlbaCastillo/Telecommunications-Data-Analyst/blob/main/EDA_Telecomunicaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importar datos

# %%
# Datos
# Se extrae directamente desde un archivo en la carpeta de drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Datos 'Internet'
Velocidad_Media_de_bajada_Internet_fijo = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Velocidad_Media_de_bajada_Internet_fijo.csv")
Velocidad_media_bajada_Internet_fijo_por_provincia = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Velocidad_media_bajada_Internet_fijo_por_provincia.csv")
Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta.csv")
Serie_trimestral_accesos_Internet_fijo_por_tecnología = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Serie_trimestral_accesos_Internet_fijo_por_tecnología.csv")
Penetración_por_hogares_nacional_Internet_fijo = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Penetración_por_hogares_nacional_Internet fijo.csv")
Penetración_de_Internet_fijo_cada_100_hogares = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Penetración_de _Internet fijo _(accesos _cada_100 hogares).csv")
Listado_localidades_conectividad_internet = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Listado_localidades_conectividad_internet.csv")
Ingresos_trimestrales_prestación_servicio_Internet_fijo = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Ingresos_trimestrales_prestación_servicio_Internet_fijo.csv")
Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad.csv")
Conectividad_al_servicio_Internet = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Conectividad_al_servicio_Internet.csv")
Accesos_Internet_fijo_por_velocidad_bajada_y_provincia = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Accesos_Internet_fijo_por_velocidad_bajada_y_provincia.csv")
Accesos_Internet_fijo_por_velocidad_bajada_y_Localidad = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Accesos_Internet_fijo_por_velocidad_bajada_y _ocalidad.csv")
Accesos_Internet_fijo_por_tecnología_y_localidad = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Accesos_Internet_fijo_por_tecnología_y_localidad.csv")
Accesos_banda_ancha_y_angosta_por_provincia = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Accesos_banda_ancha_y_angosta_por_provincia.csv")
Acceso_Internet_fijo_por_tecnología_y_provincia = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Acceso_Internet_fijo_por_tecnología_y_provincia.csv")
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Internet/Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia.csv")

# %%
# Datos 'Telefonía Movil'
Trafico_suscriptores_telefonia_movil_total_llamadas = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonía Movil/Trafico_suscriptores_telefonia_movil-total_llamadas.csv")
Trafico_suscriptores_telefonia_movil_miles_de_minutos = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonía Movil/Trafico_suscriptores_telefonia_movil-miles_de_minutos.csv")
Total_nacional_accesos_telefonia_movil_trimestral = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonía Movil/Total_nacional_accesos_telefonia_movil-trimestral.csv")
SMS_enviados = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonía Movil/SMS_enviados.csv")
Portabilidad_portaciones_netas_mensuales_por_operador = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonía Movil/Portabilidad_portaciones_netas_mensuales_por_operador.csv")
Portabilidad_altas_mensuales_por_operador = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonía Movil/Portabilidad_altas_mensuales_por_operador.csv")
Penetración_nacional_telefonia_movil_accesos_cada_100_hab = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonía Movil/Penetración_nacional_telefonia_movil-accesos_cada_100_hab.csv")
Ingresos_trimestrales_telefonía_móvil = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonía Movil/Ingresos_trimestrales_telefonía móvil.csv")

# %%
# Datos 'Telefonia Fija'
Penetracion_trimestral_telefonia_fija_por_provincia = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonia Fija/Penetracion_trimestral_telefonia_fija_por_provincia.csv")
Penetración_total_nacional_telefonía_fija_por_trimestre = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonia Fija/Penetración_total_nacional_telefonía_fija_por_trimestre.csv")
Penetración_provincial_telefonia_fija_accesos_cada_100_hogares = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonia Fija/Penetración_provincial_telefonia_fija_accesos_cada_100_hogares.csv")
Ingresos_trimestrales_telefonía_fija = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonia Fija/Ingresos_trimestrales_telefonía fija.csv")
Accesos_telefonía_fija_por_provincia_ = pd.read_csv("/content/drive/MyDrive/Telecomunicaciones - Data Analyst/Telefonia Fija/Accesos_telefonía_fija_por_provincia-hogares-comercios-gobierno-otros.csv")

# %% [markdown]
# # Data Understanding and Data Preparation

# %% [markdown]
# Cambiamos a un formato estandar, donde los valores str tengan la primera letra de cada palabra en mayuscula y el resto en minuscula y los valores numericos tengan como separador de miles vacio o ',' y como separador de decimal '.'

# %% [markdown]
# **Velocidad_Media_de_bajada_Internet_fijo
# Velocidad_media_bajada_Internet_fijo_por_provincia
# Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta
# Serie_trimestral_accesos_Internet_fijo_por_tecnología
# Penetración_por_hogares_nacional_Internet_fijo
# Penetración_de_Internet_fijo_cada_100_hogares
# Listado_localidades_conectividad_internet
# Ingresos_trimestrales_prestación_servicio_Internet_fijo
# Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad
# Conectividad_al_servicio_Internet
# Accesos_Internet_fijo_por_velocidad_bajada_y_provincia
# Accesos_Internet_fijo_por_velocidad_bajada_y_Localidad
# Accesos_Internet_fijo_por_tecnología_y_localidad
# Accesos_banda_ancha_y_angosta_por_provincia
# Acceso_Internet_fijo_por_tecnología_y_provincia
# Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia**

# %%
Velocidad_Media_de_bajada_Internet_fijo.head(2)
# Out:
#     Año  Trimestre Mbps (Media de bajada)   Trimestre.1
# 0  2022          1                  55,11  Ene-Mar 2022
# 1  2021          4                  52,34  Oct-Dic 2021

# %%
Velocidad_Media_de_bajada_Internet_fijo['Mbps (Media de bajada)'] = Velocidad_Media_de_bajada_Internet_fijo['Mbps (Media de bajada)'].str.replace(',', '.').astype(float)

# %%
def replace_commas(df, col_name):
    df[col_name] = df[col_name].astype(str).str.replace(',', '.').astype(float)
    return df

# %%
Velocidad_media_bajada_Internet_fijo_por_provincia.head(2)
# Out:
#     Año  Trimestre        Provincia  Mbps (Media de bajada)
# 0  2022          1     Buenos Aires                      63
# 1  2022          1  Capital Federal                      88

# %%
Velocidad_media_bajada_Internet_fijo_por_provincia = Velocidad_media_bajada_Internet_fijo_por_provincia.apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %%
Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta.head(2)
# Out:
#     Año  Trimestre Banda ancha fija  Dial up       Total       Periodo
# 0  2022          1       10.611.390   12.619  10.624.009  Ene-Mar 2022
# 1  2021          4       10.476.933   12.861  10.489.794  Oct-Dic 2021

# %%
def replace_int(df, col_name):
    df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)
    return df

# %%
 Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta['Banda ancha fija'] = Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta['Banda ancha fija'].str.replace('.', '').astype(int)
# Out:
# <ipython-input-298-491748a892e9>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta['Banda ancha fija'] = Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta['Banda ancha fija'].str.replace('.', '').astype(int)

# %%
Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta['Dial up'] = Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta['Dial up'].astype(str).str.replace('.', '').astype(int)
# Out:
# <ipython-input-299-468e0ff630f1>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta['Dial up'] = Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta['Dial up'].astype(str).str.replace('.', '').astype(int)

# %%
Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta['Total'] = Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta['Total'].astype(str).str.replace('.', '').astype(int)
# Out:
# <ipython-input-300-f6a3d567f1c3>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta['Total'] = Total_nacional_accesos_Internet_banda_ancha_y_banda_angosta['Total'].astype(str).str.replace('.', '').astype(int)

# %%
Serie_trimestral_accesos_Internet_fijo_por_tecnología.head(2)
# Out:
#     Año  Trimestre       ADSL Cablemodem Fibra óptica  Wireless    Otros  \
# 0  2022          1  1.533.240  6.073.426    2.219.533   545.814  251.996
# 1  2021          4  1.657.615  5.984.240    2.072.236   523.107  252.596
#
#         Total       Periodo
# 0  10.624.009  Ene-Mar 2022
# 1  10.489.794  Oct-Dic 2021

# %%
Serie_trimestral_accesos_Internet_fijo_por_tecnología.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           33 non-null     int64
#  1   Trimestre     33 non-null     int64
#  2   ADSL          33 non-null     object
#  3   Cablemodem    33 non-null     object
#  4   Fibra óptica  33 non-null     object
#  5   Wireless      33 non-null     float64
#  6   Otros         33 non-null     float64
#  7   Total         33 non-null     object
#  8   Periodo       33 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.4+ KB

# %%
Serie_trimestral_accesos_Internet_fijo_por_tecnología = replace_int(Serie_trimestral_accesos_Internet_fijo_por_tecnología, 'ADSL')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Serie_trimestral_accesos_Internet_fijo_por_tecnología = replace_int(Serie_trimestral_accesos_Internet_fijo_por_tecnología, 'Cablemodem')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Serie_trimestral_accesos_Internet_fijo_por_tecnología = replace_int(Serie_trimestral_accesos_Internet_fijo_por_tecnología, 'Fibra óptica')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Serie_trimestral_accesos_Internet_fijo_por_tecnología = replace_int(Serie_trimestral_accesos_Internet_fijo_por_tecnología, 'Wireless')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Serie_trimestral_accesos_Internet_fijo_por_tecnología = replace_int(Serie_trimestral_accesos_Internet_fijo_por_tecnología, 'Otros')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Serie_trimestral_accesos_Internet_fijo_por_tecnología = replace_int(Serie_trimestral_accesos_Internet_fijo_por_tecnología, 'Total')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Penetración_por_hogares_nacional_Internet_fijo.head(2)
# Out:
#     Año  Trimestre Accesos por cada 100 hogares Accesos por cada 100 hab  \
# 0  2022          1                        73,88                    23,05
# 1  2021          4                        73,18                    22,81
#
#         Periodo
# 0  Ene-Mar 2022
# 1  Oct-Dic 2021

# %%
Penetración_por_hogares_nacional_Internet_fijo = replace_commas(Penetración_por_hogares_nacional_Internet_fijo, 'Accesos por cada 100 hogares')

# %%
Penetración_por_hogares_nacional_Internet_fijo = replace_commas(Penetración_por_hogares_nacional_Internet_fijo, 'Accesos por cada 100 hab')

# %%
Penetración_de_Internet_fijo_cada_100_hogares.head(2)
# Out:
#     Año  Trimestre        Provincia Accesos por cada 100 hogares
# 0  2022          1     Buenos Aires                        76,08
# 1  2022          1  Capital Federal                        111,8

# %%
Penetración_de_Internet_fijo_cada_100_hogares = replace_commas(Penetración_de_Internet_fijo_cada_100_hogares, 'Accesos por cada 100 hogares')

# %%
Penetración_de_Internet_fijo_cada_100_hogares = Penetración_de_Internet_fijo_cada_100_hogares.apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %%
Listado_localidades_conectividad_internet.head(2)
# Out:
#       Provincia     Partido        Localidad ADSL CABLEMODEM DIALUP  \
# 0  BUENOS AIRES  25 de Mayo       25 de Mayo   SI         SI     --
# 1  BUENOS AIRES  25 de Mayo  Agustín Mosconi   --         --     --
#
#   FIBRAOPTICA  4G  3G TELEFONIAFIJA WIRELESS SATELITAL
# 0          SI  SI  SI            SI       SI        SI
# 1          --  --  --            SI       --        --

# %%
Listado_localidades_conectividad_internet = Listado_localidades_conectividad_internet.replace('--', 'NO')

# %%
Listado_localidades_conectividad_internet = Listado_localidades_conectividad_internet.apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %%
Ingresos_trimestrales_prestación_servicio_Internet_fijo.head(2)
# Out:
#     Año  Trimestre Ingresos (miles de pesos)       Periodo
# 0  2022          1                51.432.896  Ene-Mar 2022
# 1  2021          4                45.467.887  Oct-Dic 2021

# %%
Ingresos_trimestrales_prestación_servicio_Internet_fijo = replace_int(Ingresos_trimestrales_prestación_servicio_Internet_fijo, 'Ingresos (miles de pesos)')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad.head(2)
# Out:
#     Año  Trimestre  Hasta 512 kbps  Entre 512 Kbps y 1 Mbps  \
# 0  2022          1          34.890                  104.840
# 1  2021          4          41.262                   28.521
#
#   Entre 1 Mbps y 6 Mbps Entre 6 Mbps y 10 Mbps Entre 10 Mbps y 20 Mbps  \
# 0             1.263.273              1.209.148                 967.508
# 1             1.413.208              1.245.333                 976.539
#
#   Entre 20 Mbps y 30 Mbps Más de 30 Mbps    OTROS       Total  Unnamed: 11
# 0                 509.830      6.336.187  198.333  10.624.009          NaN
# 1                 558.358      6.032.322  194.251  10.489.794          NaN

# %%
Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad = replace_int(Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad, 'Hasta 512 kbps')
Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad = replace_int(Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad, 'Entre 512 Kbps y 1 Mbps')
Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad = replace_int(Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad, 'Entre 1 Mbps y 6 Mbps')
Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad = replace_int(Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad, 'Entre 6 Mbps y 10 Mbps')
Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad = replace_int(Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad, 'Entre 10 Mbps y 20 Mbps')
Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad = replace_int(Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad, 'Entre 20 Mbps y 30 Mbps')
Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad = replace_int(Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad, 'Más de 30 Mbps')
Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad = replace_int(Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad, 'OTROS')
Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad = replace_int(Distribución_accesos_totales_nacionales_internet_fijo_por_velocidad, 'Total')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Conectividad_al_servicio_Internet.head(2)
# Out:
#       Provincia     Partido        Localidad  Poblacion ADSL CABLEMODEM  \
# 0  BUENOS AIRES  25 de Mayo       25 de Mayo      23408   SI         SI
# 1  BUENOS AIRES  25 de Mayo  Agustín Mosconi        280   --         --
#
#   DIALUP FIBRAOPTICA SATELITAL WIRELESS TELEFONIAFIJA  3G  4G       link  \
# 0     --          SI        SI       SI            SI  SI  SI  6854100.0
# 1     --          --        --       --            SI  --  --  6854010.0
#
#      Latitud   Longitud
# 0 -35.433939 -60.173121
# 1 -35.739217 -60.559063

# %%
Conectividad_al_servicio_Internet = Conectividad_al_servicio_Internet.replace('--', 'NO')

# %%
Conectividad_al_servicio_Internet = Conectividad_al_servicio_Internet.apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %%
Accesos_Internet_fijo_por_velocidad_bajada_y_provincia.head(2)
# Out:
#       Año  Trimestre        Provincia   Otros 0,256 Mbps 0,375 Mbps  \
# 0  2022.0        1.0     Buenos Aires  26,280         19        - 0
# 1  2022.0        1.0  Capital Federal   1,717         31        - 0
#
#   0,625 Mbps 0,5 Mbps 0,512 Mbps 0,75 Mbps  ... 70 Mbps 71 Mbps  75 Mbps  \
# 0        - 0   31,380        192     5,958  ...   3,163     - 0  100,884
# 1        - 0      461         35     1,407  ...       3     - 0   31,684
#
#   77 Mbps 78 Mbps 80 Mbps 81 Mbps 83 Mbps 82 Mbps 86 Mbps
# 0     - 0       4     212     - 0       2     - 0     - 0
# 1     - 0     - 0       8     - 0     - 0     - 0     - 0
#
# [2 rows x 97 columns]

# %%
Accesos_Internet_fijo_por_velocidad_bajada_y_provincia = Accesos_Internet_fijo_por_velocidad_bajada_y_provincia.replace('- 0', '0')

# %%
Accesos_Internet_fijo_por_velocidad_bajada_y_provincia = Accesos_Internet_fijo_por_velocidad_bajada_y_provincia.apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %%
Accesos_Internet_fijo_por_velocidad_bajada_y_Localidad.head(2)
# Out:
#       Provincia     Partido        Localidad Link Indec  Otros  0,256 Mbps  \
# 0  BUENOS AIRES  25 de Mayo       25 de Mayo    6854100    NaN         NaN
# 1  BUENOS AIRES  25 de Mayo  Agustín Mosconi    6854010    NaN         NaN
#
#    0,375 Mbps  0,5 Mbps  0,512 Mbps  0,625 Mbps  ...  75 Mbps  78 Mbps  \
# 0         NaN       2.0         NaN         NaN  ...      NaN      NaN
# 1         NaN       NaN         NaN         NaN  ...      NaN      NaN
#
#    80 Mbps  82 Mbps  83 Mbps  85 Mbps  90 Mbps  92 Mbps  95 Mbps  100 Mbps
# 0      9.0      NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN       NaN
#
# [2 rows x 83 columns]

# %%
Accesos_Internet_fijo_por_velocidad_bajada_y_Localidad = Accesos_Internet_fijo_por_velocidad_bajada_y_Localidad.apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %%
Accesos_Internet_fijo_por_tecnología_y_localidad.head()
# Out:
#       Provincia     Partido               Localidad Link Indec ADSL  \
# 0  BUENOS AIRES  25 de Mayo              25 de Mayo    6854100  914
# 1  BUENOS AIRES  25 de Mayo               Del Valle    6854020  181
# 2  BUENOS AIRES  25 de Mayo       Gobernador Ugarte    6854040  - 0
# 3  BUENOS AIRES  25 de Mayo  Norberto de la Riestra    6854060  - 0
# 4  BUENOS AIRES  25 de Mayo        Lucas Monteverde    6854050  - 0
#
#   CABLEMODEM DIAL UP FIBRA OPTICA OTROS SATELITAL WIMAX WIRELESS  \
# 0      4.704     - 0            5   - 0       975   - 0      664
# 1        - 0     - 0          - 0    10         1   - 0      - 0
# 2        - 0     - 0          - 0   - 0       - 0   - 0      181
# 3        782     - 0          - 0    18       - 0   - 0      327
# 4        - 0     - 0          - 0   - 0       - 0   - 0        6
#
#   Total general  Unnamed: 13
# 0         7.262          NaN
# 1           192          NaN
# 2           181          NaN
# 3         1.127          NaN
# ...

# %%
Accesos_Internet_fijo_por_tecnología_y_localidad = Accesos_Internet_fijo_por_tecnología_y_localidad.replace('- 0', '0')
Accesos_Internet_fijo_por_tecnología_y_localidad = replace_int(Accesos_Internet_fijo_por_tecnología_y_localidad, 'ADSL')
Accesos_Internet_fijo_por_tecnología_y_localidad = replace_int(Accesos_Internet_fijo_por_tecnología_y_localidad, 'CABLEMODEM')
Accesos_Internet_fijo_por_tecnología_y_localidad = replace_int(Accesos_Internet_fijo_por_tecnología_y_localidad, 'DIAL UP')
Accesos_Internet_fijo_por_tecnología_y_localidad = replace_int(Accesos_Internet_fijo_por_tecnología_y_localidad, 'FIBRA OPTICA')
Accesos_Internet_fijo_por_tecnología_y_localidad = replace_int(Accesos_Internet_fijo_por_tecnología_y_localidad, 'OTROS')
Accesos_Internet_fijo_por_tecnología_y_localidad = replace_int(Accesos_Internet_fijo_por_tecnología_y_localidad, 'SATELITAL')
Accesos_Internet_fijo_por_tecnología_y_localidad = replace_int(Accesos_Internet_fijo_por_tecnología_y_localidad, 'WIMAX')
Accesos_Internet_fijo_por_tecnología_y_localidad = replace_int(Accesos_Internet_fijo_por_tecnología_y_localidad, 'WIRELESS')
Accesos_Internet_fijo_por_tecnología_y_localidad = replace_int(Accesos_Internet_fijo_por_tecnología_y_localidad, 'Total general')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Accesos_Internet_fijo_por_tecnología_y_localidad= Accesos_Internet_fijo_por_tecnología_y_localidad.apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %%
Accesos_banda_ancha_y_angosta_por_provincia.head(2)
# Out:
#     Año  Trimestre        Provincia Banda ancha fija Dial up      Total
# 0  2022          1     Buenos Aires        4.549.131   6.293  4.555.424
# 1  2022          1  Capital Federal        1.415.378   2.163  1.417.541

# %%
null_rows = Accesos_banda_ancha_y_angosta_por_provincia[Accesos_banda_ancha_y_angosta_por_provincia.isnull().any(axis=1)]
print(null_rows)
# Out:
#       Año  Trimestre Provincia Banda ancha fija Dial up    Total
# 368  2018          2   Formosa           44.554     NaN   44.554
# 373  2018          2  Misiones          106.147     NaN  106.147

# %%
Accesos_banda_ancha_y_angosta_por_provincia.fillna(value=0, inplace=True)

# %%
Accesos_banda_ancha_y_angosta_por_provincia = Accesos_banda_ancha_y_angosta_por_provincia.replace('- 0', '0')
Accesos_banda_ancha_y_angosta_por_provincia = replace_int(Accesos_banda_ancha_y_angosta_por_provincia, 'Banda ancha fija')
Accesos_banda_ancha_y_angosta_por_provincia = replace_int(Accesos_banda_ancha_y_angosta_por_provincia, 'Dial up')
Accesos_banda_ancha_y_angosta_por_provincia = replace_int(Accesos_banda_ancha_y_angosta_por_provincia, 'Total')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Accesos_banda_ancha_y_angosta_por_provincia = Accesos_banda_ancha_y_angosta_por_provincia .apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %%
Acceso_Internet_fijo_por_tecnología_y_provincia.head(2)
# Out:
#     Año Trimestre        Provincia     ADSL Cablemodem Fibra óptica Wireless  \
# 0  2022         1     Buenos Aires  392.045  2.728.865    1.242.121  125.521
# 1  2022         1  Capital Federal  102.290  1.217.225       62.308    5.784
#
#     Otros      Total
# 0  66.872  4.555.424
# 1  29.934  1.417.541

# %%
Acceso_Internet_fijo_por_tecnología_y_provincia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 793 entries, 0 to 792
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           793 non-null    object
#  1   Trimestre     793 non-null    object
#  2   Provincia     792 non-null    object
#  3   ADSL          792 non-null    object
#  4   Cablemodem    792 non-null    object
#  5   Fibra óptica  792 non-null    object
#  6   Wireless      792 non-null    object
#  7   Otros         792 non-null    float64
#  8   Total         792 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 55.9+ KB

# %%
null_rows = Acceso_Internet_fijo_por_tecnología_y_provincia[Acceso_Internet_fijo_por_tecnología_y_provincia.isnull().any(axis=1)]
print(null_rows)
# Out:
#     Año                                          Trimestre Provincia ADSL  \
# 792   *  Los datos provinciales no coinciden a nivel na...       NaN  NaN
#
#     Cablemodem Fibra óptica Wireless  Otros Total
# 792        NaN          NaN      NaN    NaN   NaN

# %%
Acceso_Internet_fijo_por_tecnología_y_provincia['Trimestre'].iloc[792]
# Out:
# 'Los datos provinciales no coinciden a nivel nacional, ya que se rincorporó información que no contien apertuta a nivel geográfico.'

# %%
Acceso_Internet_fijo_por_tecnología_y_provincia.drop(792, inplace=True)

# %%
Acceso_Internet_fijo_por_tecnología_y_provincia = Acceso_Internet_fijo_por_tecnología_y_provincia.replace('- 0', '0')
Acceso_Internet_fijo_por_tecnología_y_provincia = replace_int(Acceso_Internet_fijo_por_tecnología_y_provincia, 'ADSL')
Acceso_Internet_fijo_por_tecnología_y_provincia = replace_int(Acceso_Internet_fijo_por_tecnología_y_provincia, 'Cablemodem')
Acceso_Internet_fijo_por_tecnología_y_provincia = replace_int(Acceso_Internet_fijo_por_tecnología_y_provincia, 'Fibra óptica')
Acceso_Internet_fijo_por_tecnología_y_provincia = replace_int(Acceso_Internet_fijo_por_tecnología_y_provincia, 'Otros')
Acceso_Internet_fijo_por_tecnología_y_provincia = replace_int(Acceso_Internet_fijo_por_tecnología_y_provincia, 'Wireless')
Acceso_Internet_fijo_por_tecnología_y_provincia = replace_int(Acceso_Internet_fijo_por_tecnología_y_provincia, 'Total')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Acceso_Internet_fijo_por_tecnología_y_provincia = Acceso_Internet_fijo_por_tecnología_y_provincia.apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %%
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia.head()
# Out:
#     Año  Trimestre        Provincia  HASTA 512 kbps  + 512 Kbps - 1 Mbps  \
# 0  2022          1     Buenos Aires          31.591               30.056
# 1  2022          1  Capital Federal         527.000                5.575
# 2  2022          1        Catamarca          71.000              456.000
# 3  2022          1            Chaco         461.000                1.099
# 4  2022          1           Chubut         113.000                1.677
#
#   + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps  \
# 0           313.382             321.756              290.127
# 1            39.918              77.390               61.053
# 2             4.386               7.009                8.773
# 3            16.888              21.235               20.898
# 4            61.369              31.856               33.080
#
#    + 20 Mbps - 30 Mbps  + 30 Mbps   OTROS      Total
# 0              161.183  3.381.049  26.280  4.555.424
# ...

# %%
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia.fillna(0, inplace=True)

# %%
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia = Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia.replace('- 0', '0')

# %%
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia = replace_int(Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia, 'HASTA 512 kbps')
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia = replace_int(Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia, '+ 512 Kbps - 1 Mbps')
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia = replace_int(Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia, '+ 1 Mbps - 6 Mbps')
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia = replace_int(Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia, '+ 6 Mbps - 10 Mbps')
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia = replace_int(Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia, '+ 10 Mbps - 20 Mbps')
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia = replace_int(Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia, '+ 20 Mbps - 30 Mbps')
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia = replace_int(Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia, '+ 30 Mbps')
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia = replace_int(Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia, 'OTROS')
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia = replace_int(Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia, 'Total')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Año                  792 non-null    int64
#  1   Trimestre            792 non-null    int64
#  2   Provincia            792 non-null    object
#  3   HASTA 512 kbps       792 non-null    int64
#  4   + 512 Kbps - 1 Mbps  792 non-null    int64
#  5   + 1 Mbps - 6 Mbps    792 non-null    int64
#  6   + 6 Mbps - 10 Mbps   792 non-null    int64
#  7   + 10 Mbps - 20 Mbps  792 non-null    int64
#  8   + 20 Mbps - 30 Mbps  792 non-null    int64
#  9   + 30 Mbps            792 non-null    int64
#  10  OTROS                792 non-null    int64
#  11  Total                792 non-null    int64
# dtypes: int64(11), object(1)
# memory usage: 74.4+ KB

# %%
Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia = Acceso_Internet_Fijo_por_rangos_velocidad_bajada_y_provincia.apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %% [markdown]
# En base a los datasets se va a dar un enfoque a las tecnologias y a la calidad y existencia de las mismas en cierta zona

# %% [markdown]
# Con el objetivo de expandir y mejorar los servicios

# %% [markdown]
# **Se plantean las siguientes preguntas que podrian ser de valor para la empresa:**
#
# ¿Cuáles son los productos y servicios más populares entre nuestros clientes? ¿Hay algún patrón de uso que podamos identificar?
#
# ¿Cuáles son las áreas geográficas con mayor demanda de nuestros servicios? ¿Podemos expandir nuestro negocio en esas áreas o en otras áreas similares?
#
# ¿Podemos ajustar nuestros precios para ser más competitivos o mejorar nuestras ofertas para atraer más clientes?
#
# ¿Cómo está cambiando el mercado de las telecomunicaciones en general? ¿Podemos anticipar cambios en la demanda y ajustar nuestra oferta en consecuencia?
#
# ¿Cómo están cambiando las preferencias de los clientes en cuanto a la tecnología y los dispositivos? ¿Podemos ofrecer nuevos productos o servicios para satisfacer estas necesidades?
#
# ¿Cómo podemos mejorar la eficiencia y reducir los costos en nuestra empresa? ¿Podemos utilizar los datos para identificar áreas de mejora y aumentar la rentabilidad?
#
# ¿Cómo se distribuyen los ingresos trimestrales de la prestación de servicios de Internet fijo entre los diferentes servicios ofrecidos por la empresa? ¿Hay oportunidades para mejorar la rentabilidad de servicios específicos?
#
# ¿Cómo se distribuyen los accesos totales nacionales de Internet fijo entre la banda ancha y la banda angosta? ¿Hay oportunidades para mejorar la oferta de servicios de banda ancha y reducir los servicios de banda angosta?

# %% [markdown]
# **Trafico_suscriptores_telefonia_movil_total_llamadas
# Trafico_suscriptores_telefonia_movil_miles_de_minutos
# Total_nacional_accesos_telefonia_movil_trimestral
# SMS_enviados
# Portabilidad_portaciones_netas_mensuales_por_operador
# Portabilidad_altas_mensuales_por_operador
# Penetración_nacional_telefonia_movil_accesos_cada_100_hab
# Ingresos_trimestrales_telefonía_móvil**

# %%
Trafico_suscriptores_telefonia_movil_total_llamadas.head(2)
# Out:
#     Año  Trimestre Llamadas pospago salientes (miles)  \
# 0  2013          1                          3.796.547
# 1  2013          2                          4.156.872
#
#    Llamadas prepago salientes (miles)  Total de llamadas salientes (miles)  \
# 0                             3412766                              7209313
# 1                             3699387                              7856258
#
#         Periodo
# 0  Ene-Mar 2013
# 1  Abr-Jun 2013

# %%
Trafico_suscriptores_telefonia_movil_total_llamadas = replace_int(Trafico_suscriptores_telefonia_movil_total_llamadas, 'Llamadas pospago salientes (miles)')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Trafico_suscriptores_telefonia_movil_miles_de_minutos.head(2)
# Out:
#     Año  Trimestre Minutos pospago salientes (miles)  \
# 0  2013          1                         8.785.943
# 1  2013          2                         9.512.689
#
#    Minutos prepago salientes (miles)  Total de minutos salientes (miles)  \
# 0                            6582117                            15368060
# 1                            7108640                            16621329
#
#         Periodo
# 0  Ene-Mar 2013
# 1  Abr-Jun 2013

# %%
Trafico_suscriptores_telefonia_movil_miles_de_minutos = replace_int(Trafico_suscriptores_telefonia_movil_miles_de_minutos, 'Minutos pospago salientes (miles)')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Total_nacional_accesos_telefonia_movil_trimestral.head(2)
# Out:
#     Año  Trimestre Total de accesos pospago Total de accesos prepago  \
# 0  2013          1                7.761.349               57.147.608
# 1  2013          2                7.769.110               58.004.822
#
#   Total de accesos operativos       Periodo
# 0                  64.908.957  Ene-Mar 2013
# 1                  65.773.932  Abr-Jun 2013

# %%
Total_nacional_accesos_telefonia_movil_trimestral = replace_int(Total_nacional_accesos_telefonia_movil_trimestral, 'Total de accesos pospago')
Total_nacional_accesos_telefonia_movil_trimestral = replace_int(Total_nacional_accesos_telefonia_movil_trimestral, 'Total de accesos prepago')
Total_nacional_accesos_telefonia_movil_trimestral = replace_int(Total_nacional_accesos_telefonia_movil_trimestral, 'Total de accesos operativos')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
SMS_enviados.head(2)
# Out:
#     Año  Trimestre Número de SMS salientes       Periodo
# 0  2013          1          36.430.004.057  Ene-Mar 2013
# 1  2013          2          34.255.065.773  Abr-Jun 2013

# %%
SMS_enviados = replace_int(SMS_enviados, 'Número de SMS salientes')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Portabilidad_portaciones_netas_mensuales_por_operador.head(2)
# Out:
#     Año  Mes  Personal   Claro  Nextel  Movistar Periodo
# 0  2012    3   -17.000  19.000     0.0    -2.000  Mar-12
# 1  2012    4     3.508  -1.134  -189.0    -2.185  Apr-12

# %%
# Portabilidad_portaciones_netas_mensuales_por_operador = replace_int(Portabilidad_portaciones_netas_mensuales_por_operador, 'Personal')

# %%
Portabilidad_altas_mensuales_por_operador.head(2)
# Out:
#     Año  Mes Personal   Claro  Nextel Movistar Total general
# 0  2022    2   71,090  98,497     NaN   95,792       265,379
# 1  2022    1   73,717  88,856     NaN   96,240       258,813

# %%
Penetración_nacional_telefonia_movil_accesos_cada_100_hab.head(2)
# Out:
#     Año  Trimestre  Accesos por cada 100 hab       Periodo
# 0  2013          1                       154  Ene-Mar 2013
# 1  2013          2                       156  Abr-Jun 2013

# %%
Penetración_nacional_telefonia_movil_accesos_cada_100_hab = replace_int (Penetración_nacional_telefonia_movil_accesos_cada_100_hab, 'Accesos por cada 100 hab')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Ingresos_trimestrales_telefonía_móvil.head(2)
# Out:
#     Año  Trimestre  Ingresos (miles de $)       Periodo
# 0  2013          1               13135235  Ene-Mar 2013
# 1  2013          2               13970806  Abr-Jun 2013

# %%
Ingresos_trimestrales_telefonía_móvil['Ingresos (miles de $)'] = Ingresos_trimestrales_telefonía_móvil['Ingresos (miles de $)'].str.replace('$', '').str.replace('.', '').astype(int)
# Out:
# <ipython-input-419-45204b7b2584>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Ingresos_trimestrales_telefonía_móvil['Ingresos (miles de $)'] = Ingresos_trimestrales_telefonía_móvil['Ingresos (miles de $)'].str.replace('$', '').str.replace('.', '').astype(int)

# %% [markdown]
# **Se plantean las siguientes preguntas qe podrian ser de valor para la empresa:**
#
# ¿Cómo ha evolucionado el tráfico y el uso de los suscriptores de telefonía móvil a lo largo del tiempo? ¿Hay patrones de uso que puedan ser explotados para mejorar la oferta de servicios?
#
# ¿Cómo se compara la penetración de la telefonía móvil a nivel nacional con otros países o regiones? ¿Hay oportunidades para expandir el negocio en áreas con baja penetración?
#
# ¿Cómo se distribuyen los ingresos trimestrales de la telefonía móvil entre los diferentes servicios y productos ofrecidos por la empresa? ¿Hay oportunidades para mejorar la rentabilidad de servicios específicos?
#
# ¿Cómo se compara el número de SMS enviados con otros servicios ofrecidos por la empresa? ¿Hay oportunidades para mejorar la oferta de servicios de mensajería?
#
# ¿Cómo se compara el total nacional de accesos de telefonía móvil trimestral con los datos de mercado? ¿La empresa está ganando cuota de mercado o perdiendo terreno frente a la competencia?
#
# ¿Cómo se relacionan los ingresos trimestrales de la telefonía móvil con los diferentes servicios ofrecidos por la empresa? ¿Hay oportunidades para mejorar la oferta de servicios y aumentar los ingresos?

# %% [markdown]
# **Penetracion_trimestral_telefonia_fija_por_provincia
# Penetración_total_nacional_telefonía_fija_por_trimestre
# Penetración_provincial_telefonia_fija_accesos_cada_100_hogares
# Ingresos_trimestrales_telefonía_fija
# Accesos_telefonía_fija_por_provincia**

# %%
Penetracion_trimestral_telefonia_fija_por_provincia.head(2)
# Out:
#     Año  Trimestre        Provincia  Accesos telefonía fija por cada 100 hab  \
# 0  2014          1     Buenos Aires                                    26.72
# 1  2014          1  Capital Federal                                    52.66
#
#    Accesos telefonía fija por cada 100 hogares
# 0                                        85.26
# 1                                       128.57

# %%
Penetracion_trimestral_telefonia_fija_por_provincia = Penetracion_trimestral_telefonia_fija_por_provincia.apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %%
Penetración_total_nacional_telefonía_fija_por_trimestre.head(2)
# Out:
#     Año  Trimestre Accesos telefonía fija por cada 100 hab  \
# 0  2022          1                                   16,96
# 1  2021          4                                   16,74
#
#   Accesos telefonía fija por cada 100 hogares
# 0                                       54,71
# 1                                       53,88

# %%
Penetración_total_nacional_telefonía_fija_por_trimestre = replace_commas(Penetración_total_nacional_telefonía_fija_por_trimestre,'Accesos telefonía fija por cada 100 hab')
Penetración_total_nacional_telefonía_fija_por_trimestre = replace_commas(Penetración_total_nacional_telefonía_fija_por_trimestre,'Accesos telefonía fija por cada 100 hogares')

# %%
Penetración_provincial_telefonia_fija_accesos_cada_100_hogares.head(2)
# Out:
#     Año  Trimestre        Provincia Accesos telefonía fija por cada 100 hab  \
# 0  2014          1     Buenos Aires                                   26,72
# 1  2014          1  Capital Federal                                   52,66
#
#   Accesos telefonía fija por cada 100 hogares
# 0                                       85,26
# 1                                      128,57

# %%
Penetración_provincial_telefonia_fija_accesos_cada_100_hogares = replace_commas(Penetración_provincial_telefonia_fija_accesos_cada_100_hogares,'Accesos telefonía fija por cada 100 hab')
Penetración_provincial_telefonia_fija_accesos_cada_100_hogares = replace_commas(Penetración_provincial_telefonia_fija_accesos_cada_100_hogares,'Accesos telefonía fija por cada 100 hogares')

# %%
Penetración_provincial_telefonia_fija_accesos_cada_100_hogares = Penetración_provincial_telefonia_fija_accesos_cada_100_hogares.apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %%
Ingresos_trimestrales_telefonía_fija.head(2)
# Out:
#     Año  Trimestre  Ingresos (miles de $)
# 0  2014          1             2916071.75
# 1  2014          2             2974865.20

# %%
Ingresos_trimestrales_telefonía_fija['Ingresos (miles de $)'] = Ingresos_trimestrales_telefonía_fija['Ingresos (miles de $)'].str.replace('.','')
Ingresos_trimestrales_telefonía_fija['Ingresos (miles de $)'] = Ingresos_trimestrales_telefonía_fija['Ingresos (miles de $)'].str.replace(',','.').astype(float)
# Out:
# <ipython-input-373-9ed5e0f7bc53>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Ingresos_trimestrales_telefonía_fija['Ingresos (miles de $)'] = Ingresos_trimestrales_telefonía_fija['Ingresos (miles de $)'].str.replace('.','')

# %%
Accesos_telefonía_fija_por_provincia_.head(2)
# Out:
#     Año  Trimestre        Provincia Accesos telefonía fija (total)  \
# 0  2022          1     Buenos Aires                      3.340.707
# 1  2022          1  Capital Federal                      1.508.031
#
#   Accesos telefonía fija (hogares)  Accesos telefonía fija (comercial)  \
# 0                        3.044.152                             230.980
# 1                        1.374.162                             104.267
#
#    Accesos telefonía fija (gobierno)  Accesos telefonía fija (otros)
# 0                             14.831                          50.744
# 1                              6.695                          22.907

# %%
Accesos_telefonía_fija_por_provincia_ = replace_int(Accesos_telefonía_fija_por_provincia_, 'Accesos telefonía fija (total)')
Accesos_telefonía_fija_por_provincia_ = replace_int(Accesos_telefonía_fija_por_provincia_, 'Accesos telefonía fija (hogares)')
Accesos_telefonía_fija_por_provincia_ = replace_int(Accesos_telefonía_fija_por_provincia_, 'Accesos telefonía fija (comercial)')
Accesos_telefonía_fija_por_provincia_ = replace_int(Accesos_telefonía_fija_por_provincia_, 'Accesos telefonía fija (gobierno)')
Accesos_telefonía_fija_por_provincia_ = replace_int(Accesos_telefonía_fija_por_provincia_, 'Accesos telefonía fija (otros)')
# Out:
# <ipython-input-297-cbec224e5807>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col_name] = df[col_name].astype(str).str.replace('.', '').astype(int)

# %%
Accesos_telefonía_fija_por_provincia_ = Accesos_telefonía_fija_por_provincia_.apply(lambda x: x.str.title() if x.dtype == 'object' else x)

# %% [markdown]
# **Se plantean las siguientes preguntas qe podrian ser de valor para la empresa:**
#
# ¿Cómo se compara la penetración trimestral de la telefonía fija por provincia con la penetración total nacional de telefonía fija por trimestre? ¿Hay oportunidades para mejorar la expansión del negocio en áreas con baja penetración?
#
# ¿Cómo se distribuyen los ingresos trimestrales de la telefonía fija entre los diferentes servicios ofrecidos por la empresa? ¿Hay oportunidades para mejorar la rentabilidad de servicios específicos?
#
# ¿Cómo se relaciona la penetración provincial de la telefonía fija con los ingresos trimestrales de la empresa? ¿Hay oportunidades para mejorar la oferta de servicios en áreas con baja penetración y aumentar los ingresos?
#
# ¿Cómo se distribuyen los accesos de telefonía fija por provincia? ¿Hay oportunidades para mejorar la oferta de servicios en áreas con acceso limitado a la telefonía fija?

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ¿Cuáles son los productos y servicios más populares entre nuestros clientes? ¿Hay algún patrón de uso que podamos identificar?

# %%
Serie_trimestral_accesos_Internet_fijo_por_tecnología.head(1)
# Out:
#     Año  Trimestre     ADSL  Cablemodem  Fibra óptica  Wireless   Otros  \
# 0  2022          1  1533240     6073426       2219533    545814  251996
#
#       Total       Periodo
# 0  10624009  Ene-Mar 2022

# %%
Serie_trimestral_accesos_Internet_fijo_por_tecnología.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           33 non-null     int64
#  1   Trimestre     33 non-null     int64
#  2   ADSL          33 non-null     int64
#  3   Cablemodem    33 non-null     int64
#  4   Fibra óptica  33 non-null     int64
#  5   Wireless      33 non-null     int64
#  6   Otros         33 non-null     int64
#  7   Total         33 non-null     int64
#  8   Periodo       33 non-null     object
# dtypes: int64(8), object(1)
# memory usage: 2.4+ KB

# %%
# Agrupar los datos por año y sumarlos para cada tecnología de acceso
df_grouped = Serie_trimestral_accesos_Internet_fijo_por_tecnología.groupby('Año').sum()[['ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless', 'Otros']]

colors = sns.color_palette(['#3D1FFF', '#0B132B', '#FF1053', '#A13D63', '#C4CBCA'])

# Crear una gráfica de línea con diferentes colores para cada tecnología
fig, ax = plt.subplots()

for tecnologia, color in zip(df_grouped.columns, colors):
    ax.plot(df_grouped.index, df_grouped[tecnologia], label=tecnologia, color=color)


plt.title('Accesos a Internet Fijo por Tecnología y Año')
plt.xlabel('Año')
plt.ylabel('Número de Accesos')


ax.set_xticks(df_grouped.index)
ax.tick_params(axis='x', rotation=90)


ax.legend()
plt.show()
# Out:
# <ipython-input-380-3ac0d9408a5a>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped = Serie_trimestral_accesos_Internet_fijo_por_tecnología.groupby('Año').sum()[['ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless', 'Otros']]

# %%
registros_por_año = Serie_trimestral_accesos_Internet_fijo_por_tecnología['Año'].value_counts()

registros_por_año
# Out:
# 2021    4
# 2020    4
# 2019    4
# 2018    4
# 2017    4
# 2016    4
# 2015    4
# 2014    4
# 2022    1
# Name: Año, dtype: int64

# %% [markdown]
#  En el gráfico "Accesos a internet fijo por tecnología y año", se observa una disminución significativa en el número de accesos a internet fijo en el año 2022 en comparación con los años anteriores, en todas las tecnologías. Sin embargo, es importante tener en cuenta que la disminución observada en el año 2022 puede deberse al hecho de que solo se cuenta con registros de un trimestre, lo que no proporciona una imagen completa de la situación. En consecuencia, la baja en el número de accesos a internet fijo en el año 2022 podría ser una tendencia temporal y no necesariamente una disminución permanente

# %% [markdown]
# Por otro lado, es importante tener en cuenta la tendencia de aumento en el uso del cablemódem y, en menor medida pero igual en aumento, la fibra óptica, sin considerar el año 2022. Por lo que seria importante enfocarse en esas dos tecnologias y ser objeto de análisis para comprender las razones detrás de la elección de los clientes por estas, y cómo se puede implementar este conocimiento a campañas de marketing a cada grupo en particular.
#
# La segmentación de clientes y la identificación de las razones detrás de la elección de los clientes por ciertas tecnologías son factores críticos para el éxito de la empresa
#
# Caracteristicas a analizar:  ubicación geográfica y la calidad del servicio

# %%
Accesos_Internet_fijo_por_tecnología_y_localidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3127 entries, 0 to 3126
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Provincia      3127 non-null   object
#  1   Partido        3127 non-null   object
#  2   Localidad      3127 non-null   object
#  3   Link Indec     3127 non-null   object
#  4   ADSL           3127 non-null   int64
#  5   CABLEMODEM     3127 non-null   int64
#  6   DIAL UP        3127 non-null   int64
#  7   FIBRA OPTICA   3127 non-null   int64
#  8   OTROS          3127 non-null   int64
#  9   SATELITAL      3127 non-null   int64
#  10  WIMAX          3127 non-null   int64
#  11  WIRELESS       3127 non-null   int64
#  12  Total general  3127 non-null   int64
#  13  Unnamed: 13    0 non-null      float64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 342.1+ KB

# %%
# Ordenar el DataFrame por la cantidad de accesos a través de fibra óptica y seleccionar las 10 primeras provincias
grouped = Accesos_Internet_fijo_por_tecnología_y_localidad.groupby('Provincia')[['FIBRA OPTICA', 'CABLEMODEM', 'Total general']].sum()
top_10 = grouped.sort_values(by='FIBRA OPTICA', ascending=False).head(10).reset_index()

colors = sns.color_palette(['#3D1FFF', '#0B132B', '#C4CBCA'])

# Crear una gráfica de barras horizontal para mostrar las 10 localidades donde se utilizan más accesos a través de fibra óptica
ax = top_10.plot(kind='bar', x='Provincia', y=['FIBRA OPTICA', 'CABLEMODEM', 'Total general'], figsize=(10,6), color=[colors[0], colors[1], colors[2]])
ax.set_title('Las 10 localidades donde se utilizan más accesos a través de fibra óptica')
ax.set_ylabel('Cantidad de accesos')
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
grouped = Accesos_Internet_fijo_por_tecnología_y_localidad.groupby('Provincia')[['FIBRA OPTICA', 'CABLEMODEM', 'Total general']].sum()
top_10 = grouped.sort_values(by='FIBRA OPTICA', ascending=False).head(10).reset_index()
print(top_10)
# Out:
#       Provincia  FIBRA OPTICA  CABLEMODEM  Total general
# 0  Buenos Aires       1242121     2728865        4555424
# 1       Cordoba        235838      501799        1003803
# 2      Santa Fe        146552      444609         870479
# 3       Mendoza        123228       74145         275185
# 4       Tucuman         86174       62396         245584
# 5          Caba         62308     1217225        1417541
# 6         Salta         40994       98667         197515
# 7     Rio Negro         38037       45366         157374
# 8         Chaco         36662       64546         144119
# 9     Catamarca         29118       15517          62378

# %%
# Ordenar el DataFrame por la cantidad de accesos a través de fibra óptica y seleccionar las 10 primeras localidades
grouped = Accesos_Internet_fijo_por_tecnología_y_localidad.groupby('Provincia')[['FIBRA OPTICA', 'CABLEMODEM', 'Total general']].sum()
top_10 = grouped.sort_values(by='CABLEMODEM', ascending=False).head(10).reset_index()

colors = sns.color_palette(['#3D1FFF', '#0B132B', '#C4CBCA'])

# Crear una gráfica de barras horizontal para mostrar las 10 localidades donde se utilizan más accesos a través de fibra óptica
ax = top_10.plot(kind='bar', x='Provincia',  y=['CABLEMODEM','FIBRA OPTICA', 'Total general'], figsize=(10,6), color=[colors[0], colors[1], colors[2]])
ax.set_title('Las 10 localidades donde se utilizan más accesos a través de CableModem')
ax.set_ylabel('Cantidad de accesos')
plt.show()

# %% [markdown]
# Buenos Aires es la provincia con mayor población en Argentina, lo que podría influir en su posición como la provincia con más accesos de fibra óptica, cable módem y total de accesos. Sin embargo, es importante tener en cuenta que la infraestructura de redes y la adopción de tecnología también pueden ser factores importantes en la cantidad de accesos de fibra óptica y cable módem en una provincia determinada.
#
# Al analizar los datos de acceso a Internet fijo por tecnología y localidad, podemos identificar las 10 provincias con mayor número de accesos de fibra óptica, cable módem y total de accesos. Estos datos son importantes para aplicar una segmentación de clientes, ya que nos permiten identificar los mercados más prometedores para ofrecer servicios de Internet fijo por fibra óptica y cable módem, y adaptar nuestras estrategias de marketing y ventas en consecuencia.
#
# Además, al analizar la relación entre el número de accesos de fibra óptica y cable módem en cada provincia, podemos identificar patrones y tendencias en la adopción de tecnología y las preferencias de los consumidores en diferentes regiones de Argentina. Esto nos puede ayudar a entender mejor las necesidades y preferencias de nuestros clientes y a desarrollar productos y servicios que satisfagan estas necesidades de manera efectiva.

# %%
Velocidad_media_bajada_Internet_fijo_por_provincia.head(1)
# Out:
#     Año  Trimestre     Provincia  Mbps (Media de bajada)
# 0  2022          1  Buenos Aires                      63

# %%
Velocidad_media_bajada_Internet_fijo_por_provincia['Provincia'].unique()
# Out:
# array(['Buenos Aires', 'Capital Federal', 'Catamarca', 'Chaco', 'Chubut',
#        'Córdoba', 'Corrientes', 'Entre Ríos', 'Formosa', 'Jujuy',
#        'La Pampa', 'La Rioja', 'Mendoza', 'Misiones', 'Neuquén',
#        'Río Negro', 'Salta', 'San Juan', 'San Luis', 'Santa Cruz',
#        'Santa Fe', 'Santiago Del Estero', 'Tierra Del Fuego', 'Tucumán'],
#       dtype=object)

# %%
import unicodedata
# Normalizar los valores de la columna
Velocidad_media_bajada_Internet_fijo_por_provincia['Provincia'] = Velocidad_media_bajada_Internet_fijo_por_provincia['Provincia'].apply(lambda x: unicodedata.normalize('NFKD', x).encode('ASCII', 'ignore').decode('utf-8'))

# %%
import unicodedata
# Normalizar los valores de la columna
Accesos_Internet_fijo_por_tecnología_y_localidad['Provincia'] = Accesos_Internet_fijo_por_tecnología_y_localidad['Provincia'].apply(lambda x: unicodedata.normalize('NFKD', x).encode('ASCII', 'ignore').decode('utf-8'))

# %%
#Tomamos el top 5 provincias con mas accesos
grouped = Accesos_Internet_fijo_por_tecnología_y_localidad.groupby('Provincia')[['FIBRA OPTICA']].sum()
top_5 = grouped.sort_values(by='FIBRA OPTICA', ascending=False).head(5).reset_index()

provincias_top_5 = top_5['Provincia'].tolist()

#Filtramos
df_provincias_top_5 = Velocidad_media_bajada_Internet_fijo_por_provincia.loc[Velocidad_media_bajada_Internet_fijo_por_provincia['Provincia'].isin(provincias_top_5)]
df_velocidad_media_por_provincia = df_provincias_top_5.groupby(['Provincia', 'Año'])['Mbps (Media de bajada)'].mean().reset_index()

df_velocidad_media_pivot = df_velocidad_media_por_provincia.pivot(index='Provincia', columns='Año', values='Mbps (Media de bajada)')
df_velocidad_media_pivot = df_velocidad_media_pivot.transpose()

colors = sns.color_palette(['#3D1FFF', '#0B132B', '#FF1053', '#A13D63', '#C4CBCA'])

#Graficamos
ax = df_velocidad_media_pivot.plot(kind='line', figsize=(10,6), color=colors)
ax.set_xlabel('Año')
ax.set_ylabel('Mbps (Media de bajada)')
ax.set_title('Velocidad media de bajada de Internet fijo por provincia a lo largo de los años (Top 5 por accesos de fibra óptica)')
plt.show()

# %%
#Tomamos el top 5 provincias con mas accesos
grouped = Accesos_Internet_fijo_por_tecnología_y_localidad.groupby('Provincia')[['CABLEMODEM']].sum()
top_5 = grouped.sort_values(by='CABLEMODEM', ascending=False).head(5).reset_index()

provincias_top_5 = top_5['Provincia'].tolist()

#Filtramos
df_provincias_top_5 = Velocidad_media_bajada_Internet_fijo_por_provincia.loc[Velocidad_media_bajada_Internet_fijo_por_provincia['Provincia'].isin(provincias_top_5)]
df_velocidad_media_por_provincia = df_provincias_top_5.groupby(['Provincia', 'Año'])['Mbps (Media de bajada)'].mean().reset_index()

df_velocidad_media_pivot = df_velocidad_media_por_provincia.pivot(index='Provincia', columns='Año', values='Mbps (Media de bajada)')
df_velocidad_media_pivot = df_velocidad_media_pivot.transpose()

colors = sns.color_palette(['#3D1FFF', '#0B132B', '#FF1053', '#A13D63', '#C4CBCA'])

#Graficamos
ax = df_velocidad_media_pivot.plot(kind='line', figsize=(10,6), color=colors)
ax.set_xlabel('Año')
ax.set_ylabel('Mbps (Media de bajada)')
ax.set_title('Velocidad media de bajada de Internet fijo por provincia a lo largo de los años (Top 5 por accesos de CABLEMODEM)')
plt.show()

# %% [markdown]
# Se observa un patrón de aumento constante en la velocidad de bajada del internet fijo en las cinco provincias con mayor acceso a la tecnología de fibra óptica y cablemódem. Este aumento sugiere que los usuarios de estas tecnologías pueden estar prefiriéndolas debido a su capacidad para ofrecer velocidades de descarga más rápidas y confiables en comparación con otras tecnologías de acceso a la internet fija

# %%
Velocidad_Media_de_bajada_Internet_fijo.head(1)
# Out:
#     Año  Trimestre  Mbps (Media de bajada)   Trimestre.1
# 0  2022          1                   55.11  Ene-Mar 2022

# %%
# Crear una nueva columna "Periodo" con la combinación de las columnas "Año" y "Trimestre"
Velocidad_Media_de_bajada_Internet_fijo['Periodo'] = Velocidad_Media_de_bajada_Internet_fijo['Año'].astype(str) + 'Q' + Velocidad_Media_de_bajada_Internet_fijo['Trimestre'].astype(str)

# Convertir la serie a un objeto PeriodIndex de pandas
periods = pd.PeriodIndex(Velocidad_Media_de_bajada_Internet_fijo['Periodo'], freq='Q')

# Convertir el PeriodIndex a un objeto DateTimeIndex de pandas
dates = periods.to_timestamp()
Velocidad_Media_de_bajada_Internet_fijo.set_index('Periodo', inplace=True)

fig, ax = plt.subplots(figsize=(10, 6))
for year in Velocidad_Media_de_bajada_Internet_fijo['Año'].unique():
    df_year = Velocidad_Media_de_bajada_Internet_fijo[Velocidad_Media_de_bajada_Internet_fijo['Año'] == year]
    ax.plot(df_year.index, df_year['Mbps (Media de bajada)'], label=str(year))

ax.legend()
ax.set_xlabel('Trimestre')
ax.set_ylabel('Mbps (Media de bajada)')
ax.set_title('Velocidad Media de Bajada de Internet Fijo por Trimestre')
ax.tick_params(axis='x', rotation=90)
plt.show()

# %% [markdown]
# Esto puede tener un impacto positivo en la experiencia del usuario, permitiendo descargar y cargar contenido más rápido, transmitir videos con mayor calidad y estabilidad, y realizar otras actividades en línea de manera más eficiente. Lo que hace tener mayor probabilidad de mantener a los clientes a largo plazo y obtener nuevos

# %%
Ingresos_trimestrales_prestación_servicio_Internet_fijo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Año                        33 non-null     int64
#  1   Trimestre                  33 non-null     int64
#  2   Ingresos (miles de pesos)  33 non-null     int64
#  3   Periodo                    33 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 1.2+ KB

# %%
Ingresos_trimestrales_telefonía_móvil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Año                    37 non-null     int64
#  1   Trimestre              37 non-null     int64
#  2   Ingresos (miles de $)  37 non-null     int64
#  3   Periodo                37 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 1.3+ KB

# %%
Ingresos_trimestrales_telefonía_fija.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Año                    33 non-null     int64
#  1   Trimestre              33 non-null     int64
#  2   Ingresos (miles de $)  33 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 920.0 bytes

# %%
df1_grouped = Ingresos_trimestrales_prestación_servicio_Internet_fijo.groupby('Año').sum()[['Ingresos (miles de pesos)']]
df2_grouped = Ingresos_trimestrales_telefonía_móvil.groupby('Año').sum()[['Ingresos (miles de $)']]
df3_grouped = Ingresos_trimestrales_telefonía_fija.groupby('Año').sum()[['Ingresos (miles de $)']]

fig, ax = plt.subplots()
colors = sns.color_palette(['#3D1FFF', '#0B132B', '#FF1053', '#A13D63', '#C4CBCA'])

ax.plot(df1_grouped.index, df1_grouped['Ingresos (miles de pesos)'], label='Internet Fijo',color=colors[0])
ax.plot(df2_grouped.index, df2_grouped['Ingresos (miles de $)'], label='Telefonia Movil',color=colors[1])
ax.plot(df3_grouped.index, df3_grouped['Ingresos (miles de $)'], label='Telefonia Fija',color=colors[2])

plt.title('Ingresos por Año')
plt.xlabel('Año')
plt.ylabel('Ingreso')

ax.set_xticks(df_grouped.index)
ax.tick_params(axis='x', rotation=90)

ax.legend()
plt.show()
# Out:
# <ipython-input-428-10431ec31a06>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1_grouped = Ingresos_trimestrales_prestación_servicio_Internet_fijo.groupby('Año').sum()[['Ingresos (miles de pesos)']]
# <ipython-input-428-10431ec31a06>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2_grouped = Ingresos_trimestrales_telefonía_móvil.groupby('Año').sum()[['Ingresos (miles de $)']]

# %% [markdown]
# Esto sugiere que el servicio de Telefonía Móvil es el más popular y rentable de los tres servicios, seguido de Internet Fijo y luego de Telefonía Fija

# %% [markdown]
# ## Dataframes Utilizados:

# %% [markdown]
# Serie_trimestral_accesos_Internet_fijo_por_tecnología
#
# Accesos_Internet_fijo_por_tecnología_y_localidad
#
# Velocidad_media_bajada_Internet_fijo_por_provincia
#
# Velocidad_Media_de_bajada_Internet_fijo
#
# Ingresos_trimestrales_prestación_servicio_Internet_fijo
#
# Ingresos_trimestrales_telefonía_móvil
#
# Ingresos_trimestrales_telefonía_fija

# %% [markdown]
# # KPI's

# %% [markdown]
# Que es lo mas importante para un cliente de una empresa de telecomunicaciones, la calidad del servicio, lo que suele incluir la disponibilidad y la velocidad con la que se puede comunicar. También es importante destacar la transparencia en los precios y los planes ofrecidos asi como garantizar la seguridad y la privacidad de la información:
#
# En base a la informacion proporcionada podemos medir el desempeño de la empresa con los siguientes KPI's
#
# **1 . Velocidad de carga y descarga**: La velocidad de carga y descarga de la conexión a internet es una medida importante para determinar la calidad del servicio que se está ofreciendo.
#
# **2 . Clientes activos**: puede ser un indicador importante del alcance de la empresa, ya que cuantos más clientes tenga, mayor será su presencia en el mercado y mayor será su capacidad para generar ingresos y ganancias.
#
# **3 . Alcance geográfico**: medido en términos de la cantidad de países o regiones en los que la empresa tiene presencia o realiza operaciones. Este KPI puede ser útil para medir el nivel de expansión internacional de la empresa y su capacidad para llegar a nuevos mercados
